# %%
# Importing necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Step 1: Load the dataset

# Load the dataset into a pandas DataFrame
df = pd.read_csv('NYPD_Motor_Vehicle_Collisions_1000.csv') 
df.head()
# Out:
#          DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  03/15/2016   0:30  MANHATTAN   10003.0  40.735270 -73.982346
# 1  06/25/2013  13:40        NaN       NaN        NaN        NaN
# 2  09/15/2012  23:10     QUEENS   11418.0  40.695822 -73.821102
# 3  03/14/2018  10:00        NaN       NaN  40.699017 -73.806960
# 4  06/06/2018  19:45      BRONX   10454.0  40.807770 -73.910230
#
#                     LOCATION                    ON STREET NAME  \
# 0     (40.73527, -73.982346)                               NaN
# 1                        NaN                               NaN
# 2  (40.6958225, -73.8211022)  ATLANTIC AVENUE
# 3     (40.699017, -73.80696)  SUTPHIN BOULEVARD
# 4      (40.80777, -73.91023)  CONCORD AVENUE
#
#                   CROSS STREET NAME                           OFF STREET NAME  \
# 0                               NaN  300       EAST 19 STREET
# 1                               NaN                                       NaN
# 2  127 STREET                                                             NaN
# 3                               NaN                                       NaN
# 4                   EAST 142 STREET                                       NaN
#
#    ...   CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0  ...                     Unspecified                            NaN
# 1  ...                     Unspecified                            NaN
# 2  ...                     Unspecified                            NaN
# 3  ...  Driver Inattention/Distraction                            NaN
# 4  ...                     Unspecified                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY  \
# 0                            NaN                            NaN     3406829
# 1                            NaN                            NaN     2879485
# 2                            NaN                            NaN      204319
# 3                            NaN                            NaN     3862996
# 4                            NaN                            NaN     3915520
#
#    VEHICLE TYPE CODE 1             VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 0    PASSENGER VEHICLE               PASSENGER VEHICLE                  NaN
# 1    PASSENGER VEHICLE  LARGE COM VEH(6 OR MORE TIRES)                  NaN
# 2    PASSENGER VEHICLE               PASSENGER VEHICLE                  NaN
# 3    PASSENGER VEHICLE                              BU                  NaN
# 4            Carry All                           Sedan                  NaN
#
#   VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
# Step 2: Convert Categorical Variables to Binary Variables (One-Hot Encoding)
# We are interested in two columns: 'BOROUGH' and 'CONTRIBUTING FACTOR VEHICLE 1'

# Fill any missing values in 'BOROUGH' and 'CONTRIBUTING FACTOR VEHICLE 1' with 'Unknown'
df['BOROUGH'] = df['BOROUGH'].fillna('Unknown')
df['CONTRIBUTING FACTOR VEHICLE 1'] = df['CONTRIBUTING FACTOR VEHICLE 1'].fillna('Unknown')

# %%
# Convert the categorical columns into dummy variables
df_encoded = pd.get_dummies(df, columns=['BOROUGH', 'CONTRIBUTING FACTOR VEHICLE 1'], drop_first=True)

# %%
# Step 3: Data Splitting for Supervised Learning
# Partitioning the data into Training (60%), Validation (25%), and Test (15%) sets

# First, we'll split the data into a temporary train+validation and test set
train_valid_set, test_set = train_test_split(df_encoded, test_size=0.15, random_state=42)

# Now, we'll split the train+validation set into train and validation sets
train_set, validation_set = train_test_split(train_valid_set, test_size=0.294, random_state=42)  # 0.294 gives a 25% of the original data

# Confirm the sizes of the datasets
print(f"Training set size: {len(train_set)}")
print(f"Validation set size: {len(validation_set)}")
print(f"Test set size: {len(test_set)}")

# Display the transformed dataset in Jupyter Notebook
df_encoded.head()  # Display the first 5 rows of the dataset
# Out:
# Training set size: 600
# Validation set size: 250
# Test set size: 150
#          DATE   TIME  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  03/15/2016   0:30   10003.0  40.735270 -73.982346
# 1  06/25/2013  13:40       NaN        NaN        NaN
# 2  09/15/2012  23:10   11418.0  40.695822 -73.821102
# 3  03/14/2018  10:00       NaN  40.699017 -73.806960
# 4  06/06/2018  19:45   10454.0  40.807770 -73.910230
#
#                     LOCATION                    ON STREET NAME  \
# 0     (40.73527, -73.982346)                               NaN
# 1                        NaN                               NaN
# 2  (40.6958225, -73.8211022)  ATLANTIC AVENUE
# 3     (40.699017, -73.80696)  SUTPHIN BOULEVARD
# 4      (40.80777, -73.91023)  CONCORD AVENUE
#
#                   CROSS STREET NAME                           OFF STREET NAME  \
# 0                               NaN  300       EAST 19 STREET
# 1                               NaN                                       NaN
# 2  127 STREET                                                             NaN
# 3                               NaN                                       NaN
# 4                   EAST 142 STREET                                       NaN
#
#    NUMBER OF PERSONS INJURED  ...  \
# 0                        0.0  ...
# 1                        0.0  ...
# 2                        0.0  ...
# 3                        1.0  ...
# 4                        0.0  ...
#
#    CONTRIBUTING FACTOR VEHICLE 1_Prescription Medication  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    CONTRIBUTING FACTOR VEHICLE 1_Reaction to Other Uninvolved Vehicle  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    CONTRIBUTING FACTOR VEHICLE 1_Reaction to Uninvolved Vehicle  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    CONTRIBUTING FACTOR VEHICLE 1_Traffic Control Disregarded  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    CONTRIBUTING FACTOR VEHICLE 1_Turning Improperly  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    CONTRIBUTING FACTOR VEHICLE 1_Unknown  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    CONTRIBUTING FACTOR VEHICLE 1_Unsafe Lane Changing  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   CONTRIBUTING FACTOR VEHICLE 1_Unsafe Speed  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#   CONTRIBUTING FACTOR VEHICLE 1_Unspecified  \
# 0                                     False
# 1                                      True
# 2                                     False
# 3                                     False
# 4                                     False
#
#   CONTRIBUTING FACTOR VEHICLE 1_View Obstructed/Limited
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 69 columns]
